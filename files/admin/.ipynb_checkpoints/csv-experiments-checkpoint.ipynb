# %%
import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
products_data = pd.read_csv("woo-export_products-2014_07_18.csv")

# %%
products_data
# Out:
#                                     ﻿"Product Name"  \
# 0                      Party Set &#8211; Tinkerbell
# 1                    Party Set &#8211; Mickey Mouse
# 2                          Party Set &#8211; Pirate
# 3                 Party Set &#8211; Disney Princess
# 4                          Party Set &#8211; Jungle
# 5                 Party Set &#8211; Winnie-the-Pooh
# 6                            Party Set &#8211; Cars
# 7                          Baby Cot Coin Bag (Pink)
# 8                                  Baby Photo Frame
# 9                                 Baby Boy Coin Bag
# 10                               Baby Girl Coin Bag
# 11                          Teddy Bear Favor (Blue)
# 12                          Teddy Bear Favor (Pink)
# 13                              Bib Coin Bag (Blue)
# 14                              Bib Coin Bag (Pink)
# 15                                  Baby Boy Bottle
# 16                                 Baby Girl Bottle
# ...
