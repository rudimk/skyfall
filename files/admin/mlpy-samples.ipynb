# %%
# !pip install mlpy
# Out:
# Downloading/unpacking mlpy
#   Could not find any downloads that satisfy the requirement mlpy
# Cleaning up...
# No distributions at all found for mlpy
# Storing debug log for failure in /root/.pip/pip.log

# %%
# %load_ext nbupload

# %%
FileUploaderWidget()
# Out:
# Progress [************************************************* ]

# %%
# !ls -l
# Out:
# total 2720
# -rw-r--r--  1 root root  176896 Jul  8 08:32 03-IntroScipy.ipynb
# -rw-r--r--  1 root root  148447 Jul  8 08:32 04-IntroSymPy.ipynb
# -rw-r--r--  1 root root   73006 Jul 23 11:41 Octave & R Samples.ipynb
# -rw-r--r--  1 root root   22616 Jul  3 13:52 Untitled0.ipynb
# drwxr-xr-x 10 root root    4096 Jul 29 08:53 ahkab
# -rw-r--r--  1 root root   83848 Jul 29 08:53 binpy-samples.ipynb
# -rw-r--r--  1 root root   24792 Jul 24 09:20 csv-experiments.ipynb
# -rw-r--r--  1 root root   10743 Jul  5 16:00 file-widget-demo.ipynb
# -rw-r--r--  1 root root   13295 Jul 24 09:21 files-demo.ipynb
# -rw-r--r--  1 root root 1867776 Jul 29 11:34 mlpy-3.5.0.tar.gz
# -rw-r--r--  1 root root    8351 Jul 29 11:34 mlpy-samples.ipynb
# -rw-r--r--  1 root root   17362 Jul 24 11:09 sage_extension.py
# -rw-r--r--  1 root root      15 Jul 24 11:12 testhashlib.sage
# -rw-r--r--  1 root root  240735 Jul 24 11:15 theano-demo.ipynb
# ...

# %%
# !tar -xvf mlpy-3.5.0.tar.gz
# Out:
# mlpy-3.5.0/
# mlpy-3.5.0/setup.py
# mlpy-3.5.0/INSTALL.txt
# mlpy-3.5.0/docs/
# mlpy-3.5.0/docs/Makefile
# mlpy-3.5.0/docs/art/
# mlpy-3.5.0/docs/art/mlpy_logo.svg
# mlpy-3.5.0/docs/art/mlpy_logo.png
# mlpy-3.5.0/docs/source/
# mlpy-3.5.0/docs/source/selection.txt
# mlpy-3.5.0/docs/source/index.txt
# mlpy-3.5.0/docs/source/metrics.txt
# mlpy-3.5.0/docs/source/lin_regr.txt
# mlpy-3.5.0/docs/source/wavelet.txt
# mlpy-3.5.0/docs/source/install.txt
# mlpy-3.5.0/docs/source/svm.txt
# mlpy-3.5.0/docs/source/dim_red.txt
# mlpy-3.5.0/docs/source/nonlin_regr.txt
# mlpy-3.5.0/docs/source/canberra.txt
# mlpy-3.5.0/docs/source/images/
# mlpy-3.5.0/docs/source/images/ridge.png
# mlpy-3.5.0/docs/source/images/iris_pca.png
# mlpy-3.5.0/docs/source/images/lars_diabetes.png
# mlpy-3.5.0/docs/source/images/ols.png
# mlpy-3.5.0/docs/source/images/kmeans.png
# mlpy-3.5.0/docs/source/images/kernel_pca.png
# mlpy-3.5.0/docs/source/images/kfda.png
# mlpy-3.5.0/docs/source/images/iris_svm_linear.png
# ...

# %%
# !rm -r mlpy-3.5.0/

# %%
# !ls -l
# Out:
# total 2720
# -rw-r--r--  1 root root  176896 Jul  8 08:32 03-IntroScipy.ipynb
# -rw-r--r--  1 root root  148447 Jul  8 08:32 04-IntroSymPy.ipynb
# -rw-r--r--  1 root root   73006 Jul 23 11:41 Octave & R Samples.ipynb
# -rw-r--r--  1 root root   22616 Jul  3 13:52 Untitled0.ipynb
# drwxr-xr-x 10 root root    4096 Jul 29 08:53 ahkab
# -rw-r--r--  1 root root   83848 Jul 29 08:53 binpy-samples.ipynb
# -rw-r--r--  1 root root   24792 Jul 24 09:20 csv-experiments.ipynb
# -rw-r--r--  1 root root   10743 Jul  5 16:00 file-widget-demo.ipynb
# -rw-r--r--  1 root root   13295 Jul 24 09:21 files-demo.ipynb
# -rw-r--r--  1 root root 1867776 Jul 29 11:34 mlpy-3.5.0.tar.gz
# -rw-r--r--  1 root root    8351 Jul 29 11:34 mlpy-samples.ipynb
# -rw-r--r--  1 root root   17362 Jul 24 11:09 sage_extension.py
# -rw-r--r--  1 root root      15 Jul 24 11:12 testhashlib.sage
# -rw-r--r--  1 root root  240735 Jul 24 11:15 theano-demo.ipynb
# ...

# %%
# !rm -r mlpy-3.5.0.tar.gz

# %%
# !ls -l
# Out:
# total 892
# -rw-r--r--  1 root root 176896 Jul  8 08:32 03-IntroScipy.ipynb
# -rw-r--r--  1 root root 148447 Jul  8 08:32 04-IntroSymPy.ipynb
# -rw-r--r--  1 root root  73006 Jul 23 11:41 Octave & R Samples.ipynb
# -rw-r--r--  1 root root  22616 Jul  3 13:52 Untitled0.ipynb
# drwxr-xr-x 10 root root   4096 Jul 29 08:53 ahkab
# -rw-r--r--  1 root root  83848 Jul 29 08:53 binpy-samples.ipynb
# -rw-r--r--  1 root root  24792 Jul 24 09:20 csv-experiments.ipynb
# -rw-r--r--  1 root root  10743 Jul  5 16:00 file-widget-demo.ipynb
# -rw-r--r--  1 root root  13295 Jul 24 09:21 files-demo.ipynb
# -rw-r--r--  1 root root   8351 Jul 29 11:34 mlpy-samples.ipynb
# -rw-r--r--  1 root root  17362 Jul 24 11:09 sage_extension.py
# -rw-r--r--  1 root root     15 Jul 24 11:12 testhashlib.sage
# -rw-r--r--  1 root root 240735 Jul 24 11:15 theano-demo.ipynb
# -rw-r--r--  1 root root  32807 Jul 24 09:16 woo-export_products-2014_07_18.csv

# %%
FileUploaderWidget()
# Out:
# Progress [************************************************* ]

# %%
# !ls -l
